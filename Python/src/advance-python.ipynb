# %% [markdown]
# ## Magic Methods

# %% [markdown]
# 🧩 Object creation & representation
# ====================================
#
# __init__(self, …) — Initializes the object after it is created.
#
# __new__(cls, …) — Creates the object before __init__ runs.
#
# __del__(self) — Called when the object is about to be destroyed.
#
# __repr__(self) — Official string representation, used for debugging.
#
# __str__(self) — Human‑friendly string representation (used by print).
#
# __format__(self, format_spec) — Custom formatting with format() or f‑strings.
#
#
# 📦 Container behavior (list‑like or dict‑like)
# ===============================================
# __len__(self) — Returns the number of elements.
#
# __getitem__(self, key) — Access with obj[key].
#
# __setitem__(self, key, value) — Assignment with obj[key] = value.
#
# __delitem__(self, key) — Deletion with del obj[key].
#
# __contains__(self, item) — Implements item in obj.
#
# __iter__(self) — Returns an iterator.
#
# __next__(self) — Returns the next element of an iterator.
#
#
# ➕ Arithmetic operators
# =========================
# __add__ — +
#
# __sub__ — -
#
# __mul__ — *
#
# __truediv__ — /
#
# __floordiv__ — //
#
# __mod__ — %
#
# __pow__ — **

# %%
class Person:
    pass

person = Person()
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
## Basic methods
class Person:
    def __init__(self, name, age ):
        self.name = name
        self.age = age

person = Person("John", 30)
print(person)
print(person.age)
# Out:
# ...
# 30

# %%
## Basic methods overwriting __str__
class Person:
    def __init__(self, name, age ):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name},{self.age} years old!"
    
    def __repr__(self):
        return f"Person(name={self.name}, age={self.age})"
    
person = Person("John", 30)
print(person)
print(repr(person))
# Out:
# John,30 years old!
# Person(name=John, age=30)

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __repr__(self):
        return f"Point({self.x}, {self.y})"

    def __add__(self, other):
        return Point(self.x + other.x, self.y + other.y)

    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
p1 = Point(1, 2)
print(repr(p1))
# Out:
# Point(1, 2)

# %% [markdown]
# ## Custom Exception (Raise and Throw an exception)

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year = int(input("Enter the dob: "))

age = 2024 - year

try:
    if age <= 30 and age >= 20:
        print("The age is valid so you can apply for the job!")
    else:
        raise dobException
except dobException:
    print("Sorry, you are not eligible for the job! ")
# Out:
# Sorry, you are not eligible for the job!

# %% [markdown]
# ## Operator Overloading

# %%
## Math Operation with vector
 
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __sub__(self, other):
        return Vector(self.x - other.x, self.y - other.y)  
        
    def __mul__(self, other):
        return Vector(self.x * other.x, self.y * other.y)

    def __eq__(self, value):
        return self.x == value.x and self.y == value.y
    
    def __repr__(self):
        return f"Vector({self.x}, {self.y})"

# create objects of the Vector class    
v1 = Vector(1, 2)   
v2 = Vector(3, 4)   

print(v1 + v2)  # Output: Vector(4, 6)
print(v1 - v2)  # Output: Vector(-2, -2)
print(v1 * v2)  # Output: Vector(3, 8)
print(v1 == v2) # Output: False
# Out:
# Vector(4, 6)
# Vector(-2, -2)
# Vector(3, 8)
# False

# %% [markdown]
# ## Iterators

# %%
my_list = [1, 2, 3]
print(my_list)
print(type(my_list))
# Out:
# [1, 2, 3]
# <class 'list'>

# %%
iterator=iter(my_list)
print(type(iterator))
print(iterator)
# Out:
# <class 'list_iterator'>
# ...

# %%
# iterate over the list using the iterator
print(next(iterator))  # Output: 1
print(next(iterator))  # Output: 2
print(next(iterator))  # Output: 3
print(next(iterator))  # This will raise StopIteration since there are no more items to iterate over
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[87], line 2
#       1 # iterate over the list using the iterator
# ----> 2 print(next(iterator))  # Output: 1
#       3 print(next(iterator))  # Output: 2
#       4 print(next(iterator))  # Output: 3
#
# StopIteration:

# %%
iterator=iter(my_list)

try:
    print(next(iterator))  # Output: 1
    print(next(iterator))  # Output: 2
    print(next(iterator))  # Output: 3
    print(next(iterator))  # This will raise StopIteration since there are no more items to iterate over
except StopIteration:
    print("No more items to iterate over.")
# Out:
# 1
# 2
# 3
# No more items to iterate over.

# %% [markdown]
# ## Generators

# %%
def square(n):
    for i in range(n):
        yield i ** 2

for num in square(5):
    print(num)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
def my_generator():
    yield 1
    yield 2
    yield 3

# %%
gen = my_generator()
gen
# Out:
# <generator object my_generator at 0x00000291E4DA3060>

# %%
print(next(gen))  # Output: 1
print(next(gen))  # Output: 2
# Out:
# 1
# 2

# %%
for val in gen:
    print(val)
# Out:
# 3

# %%
# Practical example : Reading large files

def read_large_file(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()

# Usage
for line in read_large_file('data/example.txt'):
    print(line)
# Out:
# This is an example of writing to a file.
# This is the second line.

# %% [markdown]
# # FUNCTION COPY

# %%
# FUNCTION COPY
def welcome():
    return "Welcome!"  
welcome_copy = welcome
print(welcome_copy())  # Output: Welcome, Alice!
# Out:
# Welcome!

# %%
del welcome
print(welcome_copy())  # Output: Welcome, Alice!
# Out:
# Welcome!

# %%
print(welcome())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(welcome())
#
# NameError: name 'welcome' is not defined

# %% [markdown]
# # Closures

# %%
def main_welcome(mgs):
    def sub_welcome_method():
        print("welcome to the advance python!")
        print(mgs)
        print("please enjoy with this !")
    return sub_welcome_method()

# %%
main_welcome("Hello everyone!")
# Out:
# welcome to the advance python!
# Hello everyone!
# please enjoy with this !

# %%
def main_welcome(func):
    def sub_welcome_method():
        print("welcome to the advance python!")
        func("wekcome everyone!")
        print("please enjoy with this !")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# welcome to the advance python!
# wekcome everyone!
# please enjoy with this !

# %%
def main_welcome(func, list):
    def sub_welcome_method():
        print("welcome to the advance python!")
        print(func(list))
        print("please enjoy with this !")
    return sub_welcome_method()

# %%
main_welcome(len, [1,2,3,4])
# Out:
# welcome to the advance python!
# 4
# please enjoy with this !

# %% [markdown]
# # Decorator

# %%
def main_welcome(func):
    def sub_welcome_method():
        print("welcome to the advance python!")
        func()
        print("please enjoy with this !")
    return sub_welcome_method()

# %%
def course_instroduction():
    print("This is the advance python course!")

course_instroduction()
# Out:
# This is the advance python course!

# %%
main_welcome(course_instroduction)
# Out:
# welcome to the advance python!
# This is the advance python course!
# please enjoy with this !

# %%
@main_welcome
def course_instroduction():
    print("This is the advance python course!")
# Out:
# welcome to the advance python!
# This is the advance python course!
# please enjoy with this !

# %%
# other example of decorator
def my_decorator(func):
    def wrapper():
        print("Before the function call.")
        func()
        print("After the function call.")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello!")

# %%
say_hello()
# Out:
# Before the function call.
# Hello!
# After the function call.

# %%
# Decorators with arguments
def repeat(num_times):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(num_times):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def greet(name):
    print(f"Hello, {name}!")

greet("Alice")
# Out:
# Hello, Alice!
# Hello, Alice!
# Hello, Alice!
